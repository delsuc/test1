# %%
# %pylab inline
figsize(6,6)
N = 40
a = 2*pi/N
tt = arange(N)
qq = tt #random.permutation(tt)
X = cos(a*qq)
Y = sin(a*qq)
plot(X,Y)
plot(X,Y,'o')
plot(X[[0,N-1]],Y[[0,N-1]],'*',markersize=12)
for i in [0,N-1]: #range(N):
    text(1.15*X[i]-0.05,1.15*Y[i]-0.03,str(i+1),fontsize=12)
xticks([])
yticks([])
xlim([-1.5,1.5])
ylim([-1.5,1.5])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (-1.5, 1.5)

# %%
# %pylab inline
figsize(6,6)
N = 6
a = 2*pi/N
tt = arange(N)
qq = random.permutation(tt)
X = cos(a*tt)
Y = sin(a*tt)
quiver(X[:-1],Y[:-1],X[1:]-X[:-1],Y[1:]-Y[:-1], scale_units='xy', angles='xy', scale=1.1)
#plot(X,Y,'o')
plot(X[[0,N-1]],Y[[0,N-1]],'*',markersize=12)
for i in range(N):
    text(1.15*X[i]-0.05,1.15*Y[i]-0.03,str(i+1),fontsize=12)
xticks([])
yticks([])
xlim([-1.5,1.5])
ylim([-1.5,1.5])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (-1.5, 1.5)

# %%
# %pylab inline
figsize(6,6)
N = 25
a = 2*pi/N
tt = arange(N)
qq = random.permutation(tt)
X = cos(a*qq)
Y = sin(a*qq)
#plot(X,Y)
#plot(X,Y,'o')
quiver(X[:-1],Y[:-1],X[1:]-X[:-1],Y[1:]-Y[:-1], scale_units='xy', angles='xy', scale=1.05)
plot(X[[0,N-1]],Y[[0,N-1]],'*',markersize=12)
for i in range(N):
    text(1.15*X[i]-0.05,1.15*Y[i]-0.03,str(i+1),fontsize=12)
xticks([])
yticks([])
xlim([-1.5,1.5])
ylim([-1.5,1.5])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (-1.5, 1.5)

# %%
list(flatten(zip(X,Y)))
# Out:
# [1.0,
#  0.0,
#  -0.92977648588825146,
#  0.3681245526846777,
#  0.062790519529313291,
#  0.99802672842827156,
#  0.96858316112863108,
#  0.24868988716485479,
#  0.72896862742141155,
#  0.68454710592868873,
#  0.87630668004386358,
#  -0.48175367410171532,
#  0.062790519529313721,
#  -0.99802672842827156,
#  0.87630668004386358,
#  0.48175367410171532,
#  -0.63742398974868963,
#  0.77051324277578925,
#  -0.92977648588825124,
#  -0.36812455268467836,
#  0.30901699437494723,
#  -0.95105651629515364,
#  -0.80901699437494723,
#  -0.58778525229247336,
#  -0.63742398974868963,
#  -0.77051324277578936,
#  -0.80901699437494734,
#  0.58778525229247325,
#  0.30901699437494745,
#  0.95105651629515353,
#  -0.99211470131447788,
#  -0.12533323356430431,
#  -0.99211470131447788,
#  0.12533323356430409,
#  -0.42577929156507277,
#  0.90482705246601947,
#  0.72896862742141189,
#  -0.68454710592868828,
#  0.53582679497899666,
#  -0.84432792550201508,
#  -0.18738131458572482,
#  0.98228725072868861,
#  0.96858316112863119,
#  -0.24868988716485449,
#  -0.42577929156507216,
#  -0.9048270524660198,
#  -0.18738131458572463,
#  -0.98228725072868872,
#  0.53582679497899666,
#  0.84432792550201508]

# %%
quiver?
